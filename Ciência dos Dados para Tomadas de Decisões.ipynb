# %% [markdown]
# # Jupyter notebook_Kauã Rodrigues, Eloisa Geremia, Natali Eliza Rodrigues, Julia Fontana e Gabriel Ortolan

# %% [markdown]
# terrível odiei a atividade

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Kauã\Downloads\default_of_credit_card_clients__courseware_version_1_21_19.xls")

# %%
print(f'O número de colunas é: {df.shape[1]}')

# %%
print(f'O número de linhas (amostras) é: {df.shape[0]}')

# %%
print('Tipos de dados nas colunas:')
print(df.dtypes)

# %%
print('Resumo estatístico das colunas numéricas:')
print(df.describe())

# %%
for col in df.select_dtypes(include='object').columns:
    print(f'Frequência da coluna {col}:')
    print(df[col].value_counts())
    print('\n')

# %%
print('Número de dados faltando por coluna:')
print(df.isnull().sum())
